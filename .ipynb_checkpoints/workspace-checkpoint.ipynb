# %%
from scene.dataset_readers import readColmapSceneInfo, readSynthetic4RelightInfo
import random
import matplotlib.pyplot as plt

# %%
def display_random_images_and_masks(scene_info, num_samples=10, figsize=(15, 8)):
    """
    Display random images and their corresponding masks from a dataset.
    
    Args:
        scene_info: SceneInfo object containing camera information
        num_samples: Number of random images to display (default: 10)
        figsize: Size of the figure (default: (15, 8))
        
    Returns:
        None (displays the images and masks)
    """
    # Combine train and test cameras
    all_cameras = scene_info.train_cameras + scene_info.test_cameras
    
    # Check if we have enough cameras
    if len(all_cameras) < num_samples:
        num_samples = len(all_cameras)
        print(f"Warning: Only {num_samples} cameras available.")
    
    # Select random cameras
    random_cameras = random.sample(all_cameras, num_samples)
    
    # Create a figure with subplots
    fig, axes = plt.subplots(num_samples, 2, figsize=figsize)
    
    # If only one sample, make axes 2D
    if num_samples == 1:
        axes = axes.reshape(1, -1)
    
    # Display each image and its mask
    for i, camera in enumerate(random_cameras):
        # Display the image
        axes[i, 0].imshow(camera.image)
        axes[i, 0].set_title(f"Image: {camera.image_name}")
        axes[i, 0].axis('off')
        
        # Display the mask
        axes[i, 1].imshow(camera.image_mask)
        axes[i, 1].set_title(f"Mask: {camera.image_name}")
        axes[i, 1].axis('off')
    
    plt.tight_layout()
    plt.show()
    
    return random_cameras  # Return the selected cameras for further inspection if needed

# %%
dataset_path = "/userhome/30/alaksana/datasets/table/"  # Replace with your actual path

# Load the Colmap dataset
scene_info = readColmapSceneInfo(path=dataset_path, images="images", eval=False)
# Out:
# Reading from a COLMAP dataset:   0%|                                                            | 0/185 [00:00<?, ?it/s]
# Reading camera 4/185
# Reading from a COLMAP dataset:   2%|█                                                   | 4/185 [00:00<00:05, 34.80it/s]
# Reading camera 8/185
# Reading from a COLMAP dataset:   4%|██▏                                                 | 8/185 [00:00<00:05, 34.44it/s]
# Reading camera 12/185
# Reading from a COLMAP dataset:   6%|███▎                                               | 12/185 [00:00<00:05, 32.73it/s]
# Reading camera 16/185
# Reading from a COLMAP dataset:   9%|████▍                                              | 16/185 [00:00<00:05, 31.17it/s]
# Reading camera 20/185
# Reading from a COLMAP dataset:  11%|█████▌                                             | 20/185 [00:00<00:05, 31.02it/s]
# Reading camera 24/185
# Reading from a COLMAP dataset:  13%|██████▌                                            | 24/185 [00:00<00:05, 30.98it/s]
# Reading camera 28/185
# Reading from a COLMAP dataset:  15%|███████▋                                           | 28/185 [00:00<00:05, 30.60it/s]
# Reading camera 33/185
# Reading from a COLMAP dataset:  18%|█████████                                          | 33/185 [00:01<00:04, 33.82it/s]
# Reading camera 38/185
# Reading from a COLMAP dataset:  21%|██████████▍                                        | 38/185 [00:01<00:04, 36.19it/s]
# Reading camera 42/185
# Reading from a COLMAP dataset:  23%|███████████▌                                       | 42/185 [00:01<00:03, 36.83it/s]
# Reading camera 46/185
# Reading from a COLMAP dataset:  25%|████████████▋                                      | 46/185 [00:01<00:04, 34.73it/s]
# Reading camera 143/185
# Reading from a COLMAP dataset:  77%|██████████████████████████████████████▋           | 143/185 [00:04<00:01, 28.67it/s]
# Reading camera 147/185
# Reading from a COLMAP dataset:  79%|███████████████████████████████████████▋          | 147/185 [00:04<00:01, 29.47it/s]
# Reading camera 151/185
# Reading from a COLMAP dataset:  82%|████████████████████████████████████████▊         | 151/185 [00:04<00:01, 31.45it/s]
# Reading camera 156/185
# Reading from a COLMAP dataset:  84%|██████████████████████████████████████████▏       | 156/185 [00:04<00:00, 34.27it/s]
# Reading camera 161/185
# Reading from a COLMAP dataset:  87%|███████████████████████████████████████████▌      | 161/185 [00:05<00:00, 36.56it/s]
# Reading camera 165/185
# Reading from a COLMAP dataset:  89%|████████████████████████████████████████████▌     | 165/185 [00:05<00:00, 35.67it/s]
# Reading camera 169/185
# Reading from a COLMAP dataset:  91%|█████████████████████████████████████████████▋    | 169/185 [00:05<00:00, 34.81it/s]
# Reading camera 173/185
# Reading from a COLMAP dataset:  94%|██████████████████████████████████████████████▊   | 173/185 [00:05<00:00, 31.65it/s]
# Reading camera 177/185
# Reading from a COLMAP dataset:  96%|███████████████████████████████████████████████▊  | 177/185 [00:05<00:00, 28.58it/s]
# Reading camera 180/185
# Reading from a COLMAP dataset:  97%|████████████████████████████████████████████████▋ | 180/185 [00:05<00:00, 27.73it/s]
# Reading camera 184/185
# Reading from a COLMAP dataset:  99%|█████████████████████████████████████████████████▋| 184/185 [00:05<00:00, 28.63it/s]
# Reading camera 185/185
# Reading from a COLMAP dataset: 100%|██████████████████████████████████████████████████| 185/185 [00:05<00:00, 31.61it/s]

# %%
random_cameras = display_random_images_and_masks(scene_info, num_samples=10, figsize=(15, 20))

# Optional: Print information about the first random camera
camera = random_cameras[0]
print(f"Camera ID: {camera.uid}")
print(f"Image dimensions: {camera.width} x {camera.height}")
print(f"Image name: {camera.image_name}")
print(f"Mask dimensions: {mask.width} x {mask.height}")
# Out:
# Camera ID: 181
# Image dimensions: 648 x 420
# Image name: DSC08136
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/.alaksana/ipykernel_952426/3915845417.py in <module>
#       6 print(f"Image dimensions: {camera.width} x {camera.height}")
#       7 print(f"Image name: {camera.image_name}")
# ----> 8 print(f"Mask dimensions: {mask.width} x {mask.height}")
#
# NameError: name 'mask' is not defined

# %%
dataset2_path = "/userhome/30/alaksana/datasets/chair/"  # Replace with your actual path

# Load the Colmap dataset
scene_info2 = readSynthetic4RelightInfo(dataset2_path, False, False)
# Out:
# Reading Training Transforms

# %%
random_cameras2 = display_random_images_and_masks(scene_info2, num_samples=10, figsize=(15, 20))

# Optional: Print information about the first random camera
camera2 = random_cameras2[0]
print(f"Camera ID: {camera.uid}")
print(f"Image dimensions: {camera.width} x {camera.height}")
print(f"Image name: {camera.image_name}")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Camera ID: 154
# Image dimensions: 648 x 420
# Image name: DSC08109
